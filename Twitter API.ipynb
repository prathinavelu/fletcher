# %%
import requests
from requests_oauthlib import OAuth1

# %%
consumer_key = "cReUqRpuvE2InAkxRT5fm58T2"
consumer_secret = "rqwOEf1smPIvwSdUNCQDS55tJrDGQ6qMIr81pLIOwnhl2baXYS"
access_token = "2828159875-jF5oTVCpmW3AyTMic26GUD6ByS6ZSskTedRepU4"
access_secret = "2X59xSlGHHlKaVTwmlbLDDnodDqakAuazIHmIRA0xmM0w"

oauth = OAuth1(consumer_key,
                client_secret=consumer_secret,
                resource_owner_key=access_token,
                resource_owner_secret=access_secret)

# %%
response = requests.get("http://www.thisismetis.com")
print response.text
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
#     <meta name="viewport" content="width=device-width,initial-scale=1">
#     <meta property="og:site_name" content="Metis">
#     <meta property="og:title" content="Courses in Ruby on Rails, UX & Front-End Development, Data Science | Metis">
#     <meta property="og:description" name="description" content="Metis teaches Ruby on Rails, UX & Front-End Development and Data Science 12-week in-person bootcamps in New York City and Boston.">
#     <meta name="google-site-verification" content="TiJ-d_XlGHF2Z7HqRNg0fIN36DDIZsUdGFdRYFSL-xw">
#     <meta name="msvalidate.01" content="22B850BD914B298EDD57B1C47B24C50E">
#     <link rel="alternate" type="application/atom+xml" title="Atom Feed" href="/feed.xml" />
#     <title>Courses in Ruby on Rails, UX & Front-End Development, Data Science | Metis</title>
#
#     <script type="text/javascript">
# ...

# %%
response = requests.get("https://api.twitter.com/1.1/statuses/user_timeline.json",
                        auth=oauth)

tweets = response.json()

for key in tweets[0].keys():
    print key
# Out:
# contributors
# truncated
# text
# in_reply_to_status_id
# id
# favorite_count
# source
# retweeted
# coordinates
# entities
# in_reply_to_screen_name
# id_str
# retweet_count
# in_reply_to_user_id
# favorited
# user
# geo
# in_reply_to_user_id_str
# lang
# created_at
# in_reply_to_status_id_str
# place

# %%
for tweet in tweets:
    print tweet['text']
    print
# Out:
# @laurieskelly not as good as our discussion on big dicts and what to do if the size of your dict gets unwieldy. #unintentionalpythonpuns
#
# RT @derekwillis: "Any data scientist worth their salary will tell you that you should start with a question, NOT the data." http://t.co/eEv…
#
# RT @NASA: Now: @MAVEN2Mars has completed its planned burn to enter into orbit around Mars. Watch: http://t.co/TZKSZN8lbU http://t.co/lrs2O4…
#
# You should check this out: http://t.co/9JuYeL0XeK  It's really great for learning stuff and is made by awesome people.
#
# Soderberg studies Spielberg's staging by turning Raiders of the Ark B&amp;W and replacing all sound with Trent Raznor http://t.co/lb7y0jhBwi
#
# RT @laurieskelly: #breaking #movie #news: Data science models project a profitable Zoolander 2 with #WillFerrell on board https://t.co/mGOv…
#
# I still feel bad for #silenceofthelambdas
#
# @laurieskelly @erikhinton Wooly mammoth never mammoth mammoth so those are cool.
#
# ...

# %%
parameters = {"q": "Erik", "count":20}
response = requests.get("https://api.twitter.com/1.1/search/tweets.json",
                        params = parameters,
                        auth=oauth)


pprint.pprint( response.json()['search_metadata'])

tweets = response.json()['statuses']

print 'PAGE 1'
for tweet in tweets:
    print tweet['id'], tweet['text']
    print
#--------------------
search_url = "https://api.twitter.com/1.1/search/tweets.json"
next_page_url = search_url + response.json()['search_metadata']['next_results']

response = requests.get(next_page_url, auth=oauth)

print 'PAGE 2'
for tweet in response.json()['statuses']:
    print tweet['text']
    print
# Out:
# {u'completed_in': 0.03,
#  u'count': 20,
#  u'max_id': 522392422152953856,
#  u'max_id_str': u'522392422152953856',
#  u'next_results': u'?max_id=522392212047683583&q=Erik&count=20&include_entities=1',
#  u'query': u'Erik',
#  u'refresh_url': u'?since_id=522392422152953856&q=Erik&include_entities=1',
#  u'since_id': 0,
#  u'since_id_str': u'0'}
# PAGE 1
# 522392422152953856 RT @MiniFFs: Valle outete sich am #ComingOutDay vor Erik. Als Scherz.
# Erik hingegen meinte es ernst.
#
# 522392413995032576 @erik_nusantara mas keren sekali mas. .. *yang di belakang. .. eh. hehe
#
# 522392402796216320 RT @MiniFFs: Erik mochte das Let's Play Anmirrum. Aber die Fortsetzung Andirrum, gerade als LPT mit Valle, war noch tausendmal besser.
#
# 522392381476597760 RT @MiniFFs: Wenn Valentin aufwachte und draußen stürmte und regnete es, dann gab es nichts Schöneres, als sich an Erik zu kuscheln und wei…
#
# 522392373436108800 RT @MiniFFs: "Na, alles senkrecht?", fragte Valle.
# ...

# %%
import tweepy

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

# %%
api = tweepy.API(auth)

irmak_tweets = api.user_timeline("frrmack", count=10)

# for attr in dir(irmak_tweets[0]):
#     print attr

for tweet in irmak_tweets:
    print tweet.text
    print
# Out:
# @laurieskelly not as good as our discussion on big dicts and what to do if the size of your dict gets unwieldy. #unintentionalpythonpuns
#
# RT @derekwillis: "Any data scientist worth their salary will tell you that you should start with a question, NOT the data." http://t.co/eEv…
#
# RT @NASA: Now: @MAVEN2Mars has completed its planned burn to enter into orbit around Mars. Watch: http://t.co/TZKSZN8lbU http://t.co/lrs2O4…
#
# You should check this out: http://t.co/9JuYeL0XeK  It's really great for learning stuff and is made by awesome people.
#
# Soderberg studies Spielberg's staging by turning Raiders of the Ark B&amp;W and replacing all sound with Trent Raznor http://t.co/lb7y0jhBwi
#
# RT @laurieskelly: #breaking #movie #news: Data science models project a profitable Zoolander 2 with #WillFerrell on board https://t.co/mGOv…
#
# I still feel bad for #silenceofthelambdas
#
# @laurieskelly @erikhinton Wooly mammoth never mammoth mammoth so those are cool.
#
# ...

# %%
laurie_tweets = api.user_timeline("laurieskelly", count=10)

for tweet in laurie_tweets:
    print tweet.text
    print
# Out:
# Feeling strong urge to recruit a cabal of knuckleheads to namedrop a fake #bigdata product in their #Strataconf talks. #ApacheSkiffle
#
# RT @noahWG: LinkedIn is the most annoying and frustrating website I've been to since I last visited a half-done Geocities page... http://t.…
#
# OH at @thisismetis : "Apparently, Rob Zombie likes to cast his wife in movies." #heavymetaldatascience #metisdsbc @McBeardo
#
# @mike3d0g I certainly do.
#
# madison square park: @frrmack, @laurieskelly, @lego lady liberty. http://t.co/9XtBGhqSnX
#
# This video on the front page of pirate bay (?) is very catchy. http://t.co/96f2FMPsdc  https://t.co/Usm1hJaXbJ
#
# RT @tgrall: map reduce explained - thx Dave Chapell http://t.co/05FUyJBL3w
#
# @vlsdo @McBeardo mongo? It's a pretty popular RDBMS. surprised you've never heard of it before
#
# have been waiting for this! introducing mongoDB today w data from @McBeardo's Heavy Metal Movies #metisdsbc #mcmongo http://t.co/RRO461ueko
#
# ...

# %%
query = "#bitcoin"
max_tweets = 200

search_results = tweepy.Cursor(api.search, q=query).items(max_tweets)

for i, tweet in enumerate(search_results):
    print i, tweet.text
    print
# Out:
# 0 RT @AltCoinTracker: Now providing QR Codes � easy way to add coin to your addresses http://t.co/cEflpyyUUS #bitcoin #dogecoin #feathercoin …
#
# 1 RT @gavinandresen: I'm looking for #bitcoin-fluent economists to review a draft "Block size economics" blog post... contact me if you're in…
#
# 2 Votre http://t.co/72vvQamqXe francophone est entièrement consacré à la nouvelle crypto monnaie !   #bitcoin #gratuit
#
# 3 Daily $13,485 Dollars in Bitcoin for free! http://t.co/JbI2yqup51 #bitcoin
#   [871]
#
# 4 RT @gavinandresen: I'm looking for #bitcoin-fluent economists to review a draft "Block size economics" blog post... contact me if you're in…
#
# 5 @CaV1E Here is $0.10 worth of bitcoin for you :) @ChangeTip #bitcoin
#
# 6 RT @BitcoinNotBombs: The BearWhale in the Wild! SoundFX by @1bitbybit Check it! &gt; http://t.co/1o8GUVxch4 &lt; #bitcoin #BearWhale  @aantonop
#
# ...
